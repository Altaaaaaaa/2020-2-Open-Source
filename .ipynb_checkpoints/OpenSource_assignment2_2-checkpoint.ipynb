# %%
import requests
from bs4 import BeautifulSoup


#네이버 웹툰 페이지 파싱을 통해 총 정식 연재 작품 수 구하기
URL='https://comic.naver.com/webtoon/weekday.nhn'
html=requests.get(URL).text
soup=BeautifulSoup(html,'html.parser')

title=soup.find_all('a',{'class': 'title'})
title_list=[] ; title_num=[]

#일주일 2회 이상 연재 작품은 한 번만 데이터 수집
for x in range(len(title)):
    t=title[x].text
    if(t in title_list):
        continue
    else:
        title_list.append(t)
        title_num.append(x)

print(title_list)
# Out:
# ['인생존망', '뷰티풀 군바리', '참교육', '윈드브레이커', '소녀의 세계', '백수세끼', '바이러스X', '장씨세가 호위무사', '파이게임', '앵무살수', '만렙돌파', '유일무이 로맨스', '칼가는 소녀', '요리GO', '오늘의 순정망화', '히어로메이커', '결혼생활 그림일기', '싸이코 리벤지', '아는 여자애', '리턴 투 플레이어', '이것도 친구라고', '왕따협상', '삶이 우리를 속일지라도', '보살님이 캐리해!', '사장님을 잠금해제', '일진이 사나워', '침범', '꿈의 기업', '서브 콤플렉스', '와이키키 뱀파이어', '피플', '정보전사 202', '이중첩자', '도플갱어의 게임', '두근두근 네가 좋아서', '원하는 건 너 하나', '부산스런 웹툰', '안녕 나의 모모로', '지구멸망버튼', '여기 악마가 있어', '하슬라', '뱀파이어의 꽃', '헬로맨스', '인간의 온도', '드로잉 레시피', '모락모락 왕세자님', '블루투스', '백호랑', '평범한 8반', '결백한 사람은 없다', '여신강림', '관계의 종말', '바른연애 길잡이', '한림체육관', '랜덤채팅의 그녀!', '하루만 네가 되고 싶어', '사신소년', '후기', '호랑이 들어와요', '헬58', '중증외상센터 : 골든 아워', '신도림', '삼국지톡', '원주민 공포만화', '성인초딩', '아이레', '달콤살벌한 부부', '집이 없어', '체크포인트', '견우와 선녀', '윌유메리미', '용왕님의 셰프가 되었습니다', '빅맨', '오피스 누나 이야기', '신의 언어', '별종', '플레이, 플리', '정년이', '그놈은 흑염룡', '한강예찬', '올가미', '은주의 방 2~3부', '연우의 순정', '오파츠', '숲속의 담', '피로만땅', '완벽한 가족', '자판귀', '언메이크', '도를 아십니까', '조선홍보대행사 조대박', '그날 죽은 나는', '인문학적 감수성', '너에게만 보이는', '필살VS로맨스', '3cm 헌터', '안식의 밤', '아이고 아이고', '저세상 클라스!', '장단에 맞춰줘!', '빛빛빛', '제로게임', '고수', '전지적 독자 시점', '복학왕', '모죠의 일지', '격기3반', '튜토리얼 탑의 고인물', '여주실격!', '하렘의 남자들', '캐슬', '사상최강', '남주의 첫날밤을 가져버렸다', '원수를 사랑하라', '연놈', '고삼무쌍', '일렉시드', '닥터앤닥터 육아일기', '나쁜사람', '판타지 여동생!', '빌드업', '노곤하개', '각자의 디데이', '귀곡의 문', '정순애 식당', '마녀와 용의 신혼일기', '언덕 위의 제임스', '마른 가지에 바람처럼', '로어 올림푸스', '갓물주', '이츠마인', '방탈출', '범이올시다!', '아도나이', '미래의 골동품 가게', '얼굴천재', '새벽 두 시의 신데렐라', '평화선도부', '더 트웰브', '속보입니다', '당신의 향수', '나의 우주', '시효완성', '커넥트', '인터셉트', '기술찾아드림', '기억흔적', '천도', '스캔들', '수상한 비밀상담부', '저승사자 출입금지', 'FM보이', '스몰', '노선도', '비스타', '럭키언럭키', '연애혁명', '독립일기', '더 복서', '기기괴괴', '이두나!', '간 떨어지는 동거', '노답소녀', '나노마신', '화이트 블러드', '하드캐리', '전자오락수호대', '겟백', '무사만리행', '꽃만 키우는데 너무강함', '던전 씹어먹는 아티팩트', '병의 기록', '신비', '달라 보여도 모두 같은 가족', '당신의 과녁', '쿠베라', '트롤트랩', '선의의 경쟁', '최강전설 강해효', '자취방 신선들', '헬프미', '시월드 판타지', '롤랑롤랑', '별을 삼킨 너에게', '셧업앤댄스', '안개무덤', '우리는 요정!', '스크립토리움', '오일머니', '날 가져요', '집사레인저', '로그아웃', '겟라이프', '킬더킹', '셈하는 사이', '카루나', '소녀180', '미드나잇 체이서', '보물과 괴물의 도시', '스테어스', '불릿 6미리', '손아귀', '악령주의보', '온새미로', '깁스맨', '밤하늘에 구름운', '만물의 영장', '외모지상주의', '여성전용헬스장 진달래짐', '데드퀸', '갓 오브 하이스쿨', '재혼 황후', '1초', '개를 낳았다', '살人스타그램', '뫼신 사냥꾼', '낙향문사전', '걸어서 30분', '난약', '사냥개들', '냐한남자', '플레이어', '복학생 정순이', '구남친이 내게 반했다', '성경의 역사', '옆집친구', '가슴털 로망스', '고래별', '신상 미스터리 극장', '금혼령-조선혼인금지령', '피와 나비', '상남자', '소심한 팔레트', '얌전한 사이', '닥터 프로스트 시즌 3~4', '도롱이', '진짜 정말 맹세코 좋아해', '후덜덜덜 남극전자', '너의 미소가 함정', '구독금지', '백년게임', '트럼프', '낢다른 광화문광장 이야기', '감히', '나쁜 쪽으로', '몽홀', '9등급 뒤집기', '더 게이머', '스윗솔티', '버그', '합법해적 파르페', '매지컬 메디컬', '구주의 시간', '나의 첫번째 새벽', '프리드로우', '호랑이형님', '취사병 전설이 되다', '비질란테', '힙한남자', '초인의 시대', '스터디그룹', '왕년엔 용사님', '광장', '토끼대왕', '민간인 통제구역', '청춘 블라썸', '단편.zip', '어글리후드', '나이트런', '나를 바꿔줘', '아홉수 우리들', '회춘', '두번째 생일', '갓핑크', '태백 : 튜토리얼 맨', '탑코너', '동트는 로맨스', '팔려 온 신부', '내게 필요한 NO맨스', '남자주인공의 여자사람친구입니다', '먹이', '공유몽', '광해의 연인', '피라미드 게임', '홍시는 날 좋아해!', '열불 로맨스', '압락사스', '틴맘', '웰캄투실버라이프', '저무는 해, 시린 눈', '손 잡아 볼래?', '동네몬스터', '오늘의 노담망(望)화', '피노키오 소녀', '인간졸업', '아테나 컴플렉스', '아침을 지나 밤으로', '도사 가온', '후아유!', '왕세자 입학도', '안녕, 이바다씨', '꼬리 있는 연애', '커피도둑', '함부로 대해줘', '누군가의 로섬', '먹지마세요', '싸움독학', '열렙전사', '이번 생도 잘 부탁해', '맘마미안', '입학용병', '소녀재판', '천하제일인', '약한영웅', '도망자', '경비 배두만', '극야', '오로지 너를 이기고 싶어', '벚꽃이 흩날릴 무렵', '행성인간', 'AI가 세상을 지배한다면', '합격시켜주세용', '마법스크롤 상인 지오', '내일', '인어를 위한 수영교실', '구름이 피워낸 꽃', '두근두근 연극부', '오늘 밤만 재워줘', '판사 이한영', '가비지타임', '다이스(DICE)', '스트러글', '강남도깨비', '별이삼샵', '데빌샷', '학교정벌', '오른눈이 보는 세계', '호시탐탐', '아르세니아의 마법사', '라일락 200%', '평행도시', '잉여특공대', '선녀야 야옹해봐!', '무주의 맹시', '신이 담긴 아이', '소녀 해미', '오늘도 사랑하세요', '데이즈', 'Here U Are', '인싸라이프', '위험한 신입사원', '여름은 뜨겁다', '불발소년', '죽여주는 탐정님']

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import time

URL='https://comic.naver.com/webtoon/weekday.nhn'
driver=webdriver.Chrome('../../chromedriver_win32/chromedriver.exe')
driver.get(URL)

time.sleep(1)

artist_list=[] ; genre_list=[] ; score_list=[] ; id_list=[] ; nick_list=[] ; chat_list=[]
idlst=[] ; nicklst=[] ; chatlst=[] ; DataFrame_id={} ; DataFrame_chat={}

# %%
for i in range(5): #title_num:
    
    id_list.clear()
    nick_list.clear()
    chat_list.clear()
    
    time.sleep(1)
    
    #전체 웹툰 목록 중 월요일 첫 번째 웹툰으로 페이지 이동
    page=driver.find_elements_by_class_name('title')
    page[i].click()
    
    time.sleep(0.5)
    
    #이동한 페이지 주소 읽고, 파싱하기
    html = driver.page_source
    soup = BeautifulSoup(html,'html.parser')
    
    #작가님 닉네임 수집
    artist = soup.find_all('h2')
    artist = artist[1].find('span',{'class':'wrt_nm'}).text[8:]
    artist_list.append(artist)
    
    #작품 장르 수집
    genre=soup.find('span',{'class':'genre'}).text
    genre_list.append([genre])
    
    #최신 별점 평균 점수 수집 (최대 10화 분량)
    score = soup.find_all('strong')
    scorelist=[] ; ii=9
    while score[ii].text[0].isnumeric()==True:
        scorelist.append(float(score[ii].text))
        ii +=1
    score_list.append(sum(scorelist)/len(scorelist))
        
    time.sleep(0.5)
    
    length=driver.find_elements_by_class_name('title')
    
    driver.back()
    time.sleep(0.5)

# %%
print(genre_list)
# Out:
# [['에피소드, 액션'], ['스토리, 드라마'], ['스토리, 액션'], ['스토리, 스포츠'], ['스토리, 드라마']]

# %%
    #각 회차를 돌며 댓글 작성자 아이디 수집
    for j in range(len(length)):
        #해당 페이지의 회차 모두 가져오기
        titlenum=driver.find_elements_by_class_name('title')
        
        time.sleep(0.5)
        
        webnum=[y.text for y in titlenum]
        enterToon = driver.find_elements_by_partial_link_text(webnum[j])
        
        time.sleep(0.5)
        
        enterToon[0].click()
        
        #현재 댓글 부분 파싱이 안되는 설정이므로 src의 댓글창 페이지로 직접 이동
        #현재 URL주소 복사
        html = driver.current_url
        currentPage=html[html.find('?'):]
        
        #댓글창 페이지 URL
        URL2='https://comic.naver.com/comment/comment.nhn' + currentPage
        print('Title:',title_list[i],i,' : ',URL2)
        
        time.sleep(0.4)
        
        #댓글창 페이지 열기
        driver2 = webdriver.Chrome('../../chromedriver_win32/chromedriver.exe')
        driver2.get(URL2)
        
        time.sleep(8)
        
        while True:
            try:
                #수집 편의를 위해 클린봇 댓글 필터링 기능 해제
                driver2.find_element_by_class_name('u_cbox_cleanbot_setbutton').click()
                time.sleep(0.4)
                driver2.find_element_by_class_name('u_cbox_layer_cleanbot_checkbox').click()
                time.sleep(0.4)
                driver2.find_element_by_class_name('u_cbox_layer_cleanbot_extrabutton').click()
                time.sleep(0.4)
                break
                
            except:
                driver2.close()
                driver2 = webdriver.Chrome('../../chromedriver_win32/chromedriver.exe')
                driver2.get(URL2)
                print('driver2 ERROR')
                time.sleep(20)
                continue
        
        #베스트 댓글 아이디 목록 수집
        idbest = driver2.find_elements_by_class_name('u_cbox_id') ;jj=0 
        
        time.sleep(0.1)
        
        nickbest = driver2.find_elements_by_class_name('u_cbox_nick')
        
        time.sleep(0.4)
        
        chatbest = driver2.find_elements_by_class_name('u_cbox_contents') 
        
        time.sleep(1)
        
        while jj<len(idbest):
            id_list.append(idbest[jj].text)
            nick_list.append(nickbest[jj].text)
            chat_list.append(chatbest[jj].text)
            jj +=1
            
        time.sleep(0.3)
        
        #전체 댓글 보기 클릭 & 아이디 목록 수집
        driver2.find_element_by_partial_link_text('전체댓글').click()
        
        time.sleep(0.3)
        
        #최신 댓글부터 가장 나중의 댓글까지 창 이동하며 아이디 목록 수집
        num=0 ; start=0 ; error_back=0
        while True:
            try:
                while start<=0:
                    
                    time.sleep(0.4)
            
                    page=driver2.find_elements_by_class_name('u_cbox_num_page')
                    print('now page: ',int(page[num].text),' index: ',num)
            
                    time.sleep(0.1)
            
                    idd=driver2.find_elements_by_class_name('u_cbox_id')
            
                    time.sleep(0.1)
                
                    nickk=driver2.find_elements_by_class_name('u_cbox_nick')
                    time.sleep(0.1)
            
                    chat=driver2.find_elements_by_class_name('u_cbox_contents')
    
                    time.sleep(0.1)
            
                    while len(idd)>0:
                        id_list.append(nickk[0].text+idd[0].text)
                        #nick_list.append(nickk[0].text)
                        chat_list.append(chat[0].text)
                
                        idd.pop(0)
                        nickk.pop(0)
                        chat.pop(0)
                
                    time.sleep(0.1)
            
                    #페이지가 10의 배수이면 다음 페이지 클릭, 동일 과정 거침
                    try:
                        a=driver2.find_elements_by_class_name('u_cbox_next') #*****CLEAR v
                        if(int(page[num].text) % 10 == 0 and a[0].text != ''):
                            driver2.find_element_by_class_name('u_cbox_next').click()
                    
                            time.sleep(0.1)
                    
                            page=driver2.find_elements_by_class_name('u_cbox_num_page')
                    
                            time.sleep(0.1)
                    
                            idd=driver2.find_elements_by_class_name('u_cbox_id')
                    
                            time.sleep(0.1)
                        
                            nickk=driver2.find_elements_by_class_name('u_cbox_nick')
                            
                            time.sleep(0.1)
                    
                            chat=driver2.find_elements_by_class_name('u_cbox_contents')
                            a.clear()
                    
                            time.sleep(0.1)
            
                            while len(idd)>0:
                                id_list.append(nickk[0].text+idd[0].text)
                                #nick_list.append(nickk[0].text)
                                chat_list.append(chat[0].text)
                        
                                idd.pop(0)
                                nickk.pop(0)
                                chat.pop(0)
                            num=0
                            print('now page: ',int(page[num].text),' index: ',num)
            
                    except IndexError:
                        break
                
                    num +=1
            
                    time.sleep(0.4)
            
                    try:
                        page[num].click()
                
                    except IndexError:
                        break
            
                    page.clear()
   
                    idd.clear()
    
                    time.sleep(0.1)
        
                #댓글 페이지 닫기
                error_back=0
                driver2.close()
                break
        
            except:
                print('ERROR')
                error_back +=1
                if(error_back>10):
                    page[num].click()
                continue
                
        time.sleep(0.4)
        
        #페이지 뒤로 가기, 다시 만화 목록으로 
        driver.back()
        
        time.sleep(1)
        
        titlenum.clear()
        
        #time.sleep(0.5)
        
        enterToon.clear()
        
        #time.sleep(0.5)
        
        idbest.clear()
        nickbest.clear()
        chatbest.clear()
# Out:
#   File "<ipython-input-46-995d803f6520>", line 2
#     for j in range(len(length)):
#     ^
# IndentationError: unexpected indent

# %%
    
    #전체 정식연재 만화 창으로 이동
    time.sleep(1)
    print(title_list[i],"end")
    idlst.append(id_list.copy())
    nicklst.append(nick_list.copy())
    chatlst.append(chat_list.copy())
    
    driver.back()
    
    time.sleep(0.5)
    
    page.clear()
    
    time.sleep(0.5)
    length.clear()
    
#---------------------------------------------------크롤링 END--------------------------------------------------------------

# %%
#각 작품별로 데이터 개수가 가장 많은 작품만큼 '' (빈 값) 넣어줌
idc=idlst.copy()
max_idc=[len(z) for z in idc]

#각 작품별로 데이터 개수가 가장 많은 작품만큼 '' (빈 값) 넣어줌
for count in range(len(idc)):
    nn=max(max_idc)-len(chatlst[count])
    for plus in range(nn):
        idlst[count].append('')
        chatlst[count].append('')
        
#별점 평균 점수, 장르, 작가명 넣어줌
for count1 in range(len(idc)):
    idlst[count1].insert(0,score_list[count1])
    idlst[count1].insert(0,genre_list[count1])
    idlst[count1].insert(0,artist_list[count1])
    chatlst[count1].insert(0,score_list[count1])
    chatlst[count1].insert(0,genre_list[count1])
    chatlst[count1].insert(0,artist_list[count1])

#전체 데이터를 데이터 프레임으로 변환
total_data_id={} ; total_data_chat={} ; d=68
for diction in range(len(idc)):
    total_data_id[title_list[d]] = idlst[diction]
    total_data_chat[title_list[d]] = chatlst[diction]
    d +=1
    
Total_data_id = pd.DataFrame(total_data_id)
Total_data_chat = pd.DataFrame(total_data_chat)

#데이터 프레임을 CSV파일로 추출 내보내기(ID, CHAT 따로)
Total_data_id.to_csv('NaverWebtoon_id_tue1', mode='w')
Total_data_chat.to_csv('NaverWebtoon_tue1', mode='w')
